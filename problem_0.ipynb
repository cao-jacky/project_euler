# %%
limit = 728_000

# %%
square_sum = 0 
for i in range(limit):
    # Use only odd numbers
    if not i % 2 == 0: 
        curr_square_value = i*i
        square_sum += curr_square_value
print(square_sum)
# Out:
# 64304725333212000
