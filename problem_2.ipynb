# %%
prev_num = 0
curr_num = 1
sum = 0
while curr_num <= 4_000_000:
    if curr_num % 2 == 0:
        sum += curr_num
    prev_num, curr_num = curr_num, prev_num + curr_num

# %%
print(sum)
# Out:
# 4613732
